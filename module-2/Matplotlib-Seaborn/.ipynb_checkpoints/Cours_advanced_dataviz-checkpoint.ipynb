# %%
import pandas as pd
import seaborn as sns
data = pd.read_csv('../../../_LabData/vehicles/vehicles.csv')
data.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %%
data['Fuel Barrels/Year'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Fuel Barrels/Year', data=data)
# Out:
# <AxesSubplot:xlabel='Fuel Barrels/Year'>

# %%
sns.violinplot(x='Fuel Barrels/Year', data=data)
# Out:
# <AxesSubplot:xlabel='Fuel Barrels/Year'>

# %%
data.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %%
sns.countplot(x='Cylinders', data=data)
# Out:
# <AxesSubplot:xlabel='Cylinders', ylabel='count'>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
ts = pd.date_range(start='2021-01-01', end='2021-02-01', periods=30)
ts
# Out:
# DatetimeIndex([          '2021-01-01 00:00:00',
#                '2021-01-02 01:39:18.620689655',
#                '2021-01-03 03:18:37.241379310',
#                '2021-01-04 04:57:55.862068965',
#                '2021-01-05 06:37:14.482758620',
#                '2021-01-06 08:16:33.103448275',
#                '2021-01-07 09:55:51.724137931',
#                '2021-01-08 11:35:10.344827586',
#                '2021-01-09 13:14:28.965517241',
#                '2021-01-10 14:53:47.586206896',
#                '2021-01-11 16:33:06.206896551',
#                '2021-01-12 18:12:24.827586206',
#                '2021-01-13 19:51:43.448275862',
#                '2021-01-14 21:31:02.068965517',
#                '2021-01-15 23:10:20.689655172',
#                '2021-01-17 00:49:39.310344827',
#                '2021-01-18 02:28:57.931034482',
#                '2021-01-19 04:08:16.551724138',
#                '2021-01-20 05:47:35.172413793',
#                '2021-01-21 07:26:53.793103448',
#                '2021-01-22 09:06:12.413793103',
#                '2021-01-23 10:45:31.034482758',
#                '2021-01-24 12:24:49.655172413',
#                '2021-01-25 14:04:08.275862069',
#                '2021-01-26 15:43:26.896551724',
#                '2021-01-27 17:22:45.517241379',
#                '2021-01-28 19:02:04.137931034',
#                '2021-01-29 20:41:22.758620689',
#                '2021-01-30 22:20:41.379310345',
#                          '2021-02-01 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
data = data.loc[:29,:]
data['Time period']=ts
data.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year                   Time period
# 0               522.764706            1950 2021-01-01 00:00:00.000000000
# 1               683.615385            2550 2021-01-02 01:39:18.620689655
# 2               555.437500            2100 2021-01-03 03:18:37.241379310
# 3               683.615385            2550 2021-01-04 04:57:55.862068965
# 4               555.437500            2550 2021-01-05 06:37:14.482758620

# %%
import numpy as np

# %%
time_series = pd.DataFrame(data.groupby(data['Time period']).mean()['City MPG'])
time_series.set_index(data['Time period'], inplace=True)
time_series.head()
# Out:
#                                City MPG
# Time period
# 2021-01-01 00:00:00.000000000        18
# 2021-01-02 01:39:18.620689655        13
# 2021-01-03 03:18:37.241379310        16
# 2021-01-04 04:57:55.862068965        13
# 2021-01-05 06:37:14.482758620        14

# %%
time_series.plot()
# Out:
# <AxesSubplot:xlabel='Time period'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Make                     30 non-null     object
#  1   Model                    30 non-null     object
#  2   Year                     30 non-null     int64
#  3   Engine Displacement      30 non-null     float64
#  4   Cylinders                30 non-null     float64
#  5   Transmission             30 non-null     object
#  6   Drivetrain               30 non-null     object
#  7   Vehicle Class            30 non-null     object
#  8   Fuel Type                30 non-null     object
#  9   Fuel Barrels/Year        30 non-null     float64
#  10  City MPG                 30 non-null     int64
#  11  Highway MPG              30 non-null     int64
#  12  Combined MPG             30 non-null     int64
#  13  CO2 Emission Grams/Mile  30 non-null     float64
#  14  Fuel Cost/Year           30 non-null     int64
#  15  Time period              30 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(5), object(6)
# memory usage: 3.9+ KB

# %%
sns.scatterplot(x='City MPG', y='Highway MPG', data=data)
# Out:
# <AxesSubplot:xlabel='City MPG', ylabel='Highway MPG'>

# %%
sns.jointplot(x='City MPG', y='Highway MPG', data=data, kind='hex')

# %%
data.plot.hexbin(x='City MPG', y='Highway MPG', gridsize=25);

# %%
data.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year                   Time period
# 0               522.764706            1950 2021-01-01 00:00:00.000000000
# 1               683.615385            2550 2021-01-02 01:39:18.620689655
# 2               555.437500            2100 2021-01-03 03:18:37.241379310
# 3               683.615385            2550 2021-01-04 04:57:55.862068965
# 4               555.437500            2550 2021-01-05 06:37:14.482758620

# %%
sns.heatmap(pd.crosstab(index=data['Cylinders'], columns=data['Drivetrain']))
# Out:
# <AxesSubplot:xlabel='Drivetrain', ylabel='Cylinders'>

# %%
sns.barplot(x='Cylinders', y='Fuel Barrels/Year', data=data, estimator=lambda x: x.min())
# Out:
# <AxesSubplot:xlabel='Cylinders', ylabel='Fuel Barrels/Year'>

# %%
sns.violinplot(x='Cylinders', y='Fuel Barrels/Year', data=data)
# Out:
# <AxesSubplot:xlabel='Cylinders', ylabel='Fuel Barrels/Year'>

# %%
sns.displot(x='Fuel Barrels/Year', hue='Cylinders', data=data[data.Cylinders.isin([2, 3, 4])], kind='kde')

# %%
g = sns.pairplot(data.head(200))
g.map(sns.scatterplot)

# %%
g.map_diag(sns.histplot)

# %%
g = sns.PairGrid(data.head(100), diag_sharey=False)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)
g.map_diag(sns.kdeplot)

# %%
data[data.Cylinders.isin([4,6])].Cylinders.value_counts()
# Out:
# 6.0    18
# 4.0     8
# Name: Cylinders, dtype: int64

# %%
g = sns.PairGrid(data[data.Cylinders.isin([4,6])], hue="Cylinders")
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)
g.add_legend()

# %%
sns.regplot(x='City MPG', y='Highway MPG', data=data)
# Out:
# <AxesSubplot:xlabel='City MPG', ylabel='Highway MPG'>

# %%
data.boxplot(column="Combined MPG")
# Out:
# <AxesSubplot:>

# %%
ax = sns.boxplot(x="Fuel Type", y="Highway MPG", data=data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Regular'), Text(1, 0, 'Premium')]

# %%
cyl = [6.0,4.0]
data.Cylinders.isin(cyl)
data1 = data[data.Cylinders.isin(cyl)]
data1.shape
# Out:
# (26, 16)

# %%
ax = sns.boxplot(x="Fuel Type", y="Highway MPG", hue="Cylinders",data=data1, palette="Set3")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Regular'), Text(1, 0, 'Premium')]

# %%
sns.violinplot("Combined MPG", data=data)
# Out:
# C:\Users\mailb\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Combined MPG'>

# %%
data['Fuel Barrels/Year'].hist()
# Out:
# <AxesSubplot:>

# %%
data['Fuel Barrels/Year'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
sns.distplot(data['Fuel Barrels/Year'])
# Out:
# C:\Users\mailb\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Fuel Barrels/Year', ylabel='Density'>

# %%
sns.distplot(data['Fuel Barrels/Year'], bins=20)
# Out:
# C:\Users\mailb\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Fuel Barrels/Year', ylabel='Density'>

# %%
data['Drivetrain'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
ax = sns.barplot(x="Fuel Type", y="Highway MPG", hue="Cylinders", data=data1)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Regular'), Text(1, 0, 'Premium')]

# %%
data.sort_values(by=["CO2 Emission Grams/Mile", "City MPG", "Highway MPG"], inplace=True)
data.plot(x="CO2 Emission Grams/Mile", y=["City MPG", "Highway MPG"])
# Out:
# <AxesSubplot:xlabel='CO2 Emission Grams/Mile'>

# %%
vehicles_mean = data[["Highway MPG", "City MPG", "Drivetrain"]].groupby(["Drivetrain"]).agg("mean")
vehicles_mean.plot.bar()
# Out:
# <AxesSubplot:xlabel='Drivetrain'>
