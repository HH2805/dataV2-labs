# %%
import requests
import json
import pandas as pd
from pandas import json_normalize

# %%
# Let's send a request for events data to GitHub REST API.
# The server's response is a code as follows.

# %%
response = requests.get('https://api.github.com/events', 
                        headers={'Accept': 'application/vnd.github.v3+json'})
response
# Out:
# <Response [200]>

# %%
# Let's print it in the form of JSON structured data
response.json()

# %%
# We can analyse it in Pandas
data = pd.DataFrame(response.json())
data.head()
# Out:
#             id         type  \
# 0  15718050640  CreateEvent
# 1  15718050639  GollumEvent
# 2  15718050634    ForkEvent
# 3  15718050637  CreateEvent
# 4  15718050631   WatchEvent
#
#                                                actor  \
# 0  {'id': 28930288, 'login': 'mary725', 'display_...
# 1  {'id': 35549955, 'login': 'hidekuma', 'display...
# 2  {'id': 80644408, 'login': 'raz-joan', 'display...
# 3  {'id': 77624294, 'login': 'Vaultbank', 'displa...
# 4  {'id': 7356244, 'login': 'hyhou', 'display_log...
#
#                                                 repo  \
# 0  {'id': 352354595, 'name': 'mary725/nodejs-aws-...
# 1  {'id': 345977261, 'name': 'hidekuma/gogglekaap...
# 2  {'id': 129765340, 'name': 'learn-co-students/c...
# 3  {'id': 352354594, 'name': 'Quotafund/Quotafund...
# 4  {'id': 347064903, 'name': 'NotYetGames/WarriOr...
#
#                                              payload  public  \
# 0  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 1  {'pages': [{'page_name': '~F.3.-메모-기능-업그레이드:-메...    True
# 2  {'forkee': {'id': 352354593, 'node_id': 'MDEwO...    True
# 3  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 4                              {'action': 'started'}    True
#
#              created_at                                                org
# 0  2021-03-28T14:42:28Z                                                NaN
# 1  2021-03-28T14:42:28Z                                                NaN
# 2  2021-03-28T14:42:28Z  {'id': 8825476, 'login': 'learn-co-students', ...
# 3  2021-03-28T14:42:28Z  {'id': 81521475, 'login': 'Quotafund', 'gravat...
# 4  2021-03-28T14:42:28Z  {'id': 53127776, 'login': 'NotYetGames', 'grav...

# %%
# Let's obtain authorisation credentials on the API website
# Then resister then in a separate file. Never mention them in a Python file.

f = open('github_token.txt', 'r')
github_token = f.read()
f.close()

# %%
response = requests.get('https://api.github.com/user', 
                        headers={'Accept': 'application/vnd.github.v3+json',
                                 'Authorization': f'token {github_token}'})

# %%
from pprint import pprint
pprint(response.json())
# Out:
# {'avatar_url': 'https://avatars.githubusercontent.com/u/66469972?v=4',
#  'bio': None,
#  'blog': '',
#  'collaborators': 0,
#  'company': None,
#  'created_at': '2020-06-05T10:07:22Z',
#  'disk_usage': 185106,
#  'email': None,
#  'events_url': 'https://api.github.com/users/HH2805/events{/privacy}',
#  'followers': 0,
#  'followers_url': 'https://api.github.com/users/HH2805/followers',
#  'following': 0,
#  'following_url': 'https://api.github.com/users/HH2805/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/HH2805/gists{/gist_id}',
#  'gravatar_id': '',
#  'hireable': None,
#  'html_url': 'https://github.com/HH2805',
#  'id': 66469972,
#  'location': 'France',
#  'login': 'HH2805',
#  'name': 'Hélène',
#  'node_id': 'MDQ6VXNlcjY2NDY5OTcy',
#  'organizations_url': 'https://api.github.com/users/HH2805/orgs',
#  'owned_private_repos': 1,
#  'plan': {'collaborators': 0,
#           'name': 'free',
#           'private_repos': 10000,
#           'space': 976562499},
#  'private_gists': 0,
#  'public_gists': 0,
#  'public_repos': 6,
#  'received_events_url': 'https://api.github.com/users/HH2805/received_events',
#  'repos_url': 'https://api.github.com/users/HH2805/repos',
#  'site_admin': False,
#  'starred_url': 'https://api.github.com/users/HH2805/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/HH2805/subscriptions',
#  'total_private_repos': 1,
#  'twitter_username': None,
#  'two_factor_authentication': False,
#  'type': 'User',
#  'updated_at': '2021-03-27T21:51:14Z',
#  'url': 'https://api.github.com/users/HH2805'}

# %%
response = requests.get('https://api.github.com/user/emails', 
                        headers={'Accept': 'application/vnd.github.v3+json',
                                 'Authorization': f'token {github_token}'},
                        data=json.dumps({"emails": ["neverdisclose@tutamail.com"]}))

# %%
response.json()
# Out:
# [{'email': 'mailbox2805-ironhack@yahoo.com',
#   'primary': True,
#   'verified': True,
#   'visibility': 'private'},
#  {'email': '66469972+HH2805@users.noreply.github.com',
#   'primary': False,
#   'verified': True,
#   'visibility': None},
#  {'email': 'neverdisclose@tutamail.com',
#   'primary': False,
#   'verified': True,
#   'visibility': None}]

# %%
response = requests.delete('https://api.github.com/user/emails', 
                        headers={'Accept': 'application/vnd.github.v3+json',
                                 'Authorization': f'token {github_token}'},
                        data=json.dumps({"emails": ["#emailàsupprimer@gmail.com"]}))

# %%
response.content
# Out:
# b'{"message":"Not Found","documentation_url":"https://docs.github.com/rest/reference/users#delete-an-email-address-for-the-authenticated-user"}'

# %%
#first install pyGithub (python's wrapper for github API)
from github import Github

# First create a Github instance:

# using an access token
g = Github(github_token)
g

# %%
g.get_user().login
# Out:
# 'HH2805'

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
data_flat = flatten(data, ['actor', 'repo', 'payload', 'org'])
data_flat.head()
# Out:
#             id              type  public            created_at  actor_id  \
# 0  15714140801  PullRequestEvent    True  2021-03-27T18:52:48Z  62903311
# 1  15714140794         PushEvent    True  2021-03-27T18:52:48Z  39814207
# 2  15714140798  PullRequestEvent    True  2021-03-27T18:52:48Z  29139614
# 3  15714140795         PushEvent    True  2021-03-27T18:52:48Z  78318812
# 4  15714140786         PushEvent    True  2021-03-27T18:52:48Z   7167300
#
#       actor_login actor_display_login actor_gravatar_id  \
# 0           osha7               osha7
# 1       pull[bot]                pull
# 2   renovate[bot]            renovate
# 3    I-Dvorianska        I-Dvorianska
# 4  MikhailKasimov      MikhailKasimov
#
#                                      actor_url  \
# 0           https://api.github.com/users/osha7
# 1       https://api.github.com/users/pull[bot]
# 2   https://api.github.com/users/renovate[bot]
# 3    https://api.github.com/users/I-Dvorianska
# 4  https://api.github.com/users/MikhailKasimov
#
#                                     actor_avatar_url  ...  \
# 0  https://avatars.githubusercontent.com/u/62903311?  ...
# 1  https://avatars.githubusercontent.com/u/39814207?  ...
# 2  https://avatars.githubusercontent.com/u/29139614?  ...
# 3  https://avatars.githubusercontent.com/u/78318812?  ...
# 4   https://avatars.githubusercontent.com/u/7167300?  ...
#
#   payload_master_branch payload_description payload_pusher_type payload_issue  \
# 0                   NaN                 NaN                 NaN           NaN
# 1                   NaN                 NaN                 NaN           NaN
# 2                   NaN                 NaN                 NaN           NaN
# 3                   NaN                 NaN                 NaN           NaN
# 4                   NaN                 NaN                 NaN           NaN
#
#   payload_comment    org_id   org_login org_gravatar_id  \
# 0             NaN       NaN         NaN             NaN
# 1             NaN       NaN         NaN             NaN
# 2             NaN  34368859  exportarts
# 3             NaN       NaN         NaN             NaN
# 4             NaN       NaN         NaN             NaN
#
#                                   org_url  \
# 0                                     NaN
# 1                                     NaN
# 2  https://api.github.com/orgs/exportarts
# 3                                     NaN
# 4                                     NaN
#
#                                       org_avatar_url
# 0                                                NaN
# 1                                                NaN
# 2  https://avatars.githubusercontent.com/u/34368859?
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 34 columns]

# %%
flattened = pd.DataFrame(dict(data['actor'])).transpose()
flattened.head()
# Out:
#          id           login   display_login gravatar_id  \
# 0  62903311           osha7           osha7
# 1  39814207       pull[bot]            pull
# 2  29139614   renovate[bot]        renovate
# 3  78318812    I-Dvorianska    I-Dvorianska
# 4   7167300  MikhailKasimov  MikhailKasimov
#
#                                            url  \
# 0           https://api.github.com/users/osha7
# 1       https://api.github.com/users/pull[bot]
# 2   https://api.github.com/users/renovate[bot]
# 3    https://api.github.com/users/I-Dvorianska
# 4  https://api.github.com/users/MikhailKasimov
#
#                                           avatar_url
# 0  https://avatars.githubusercontent.com/u/62903311?
# 1  https://avatars.githubusercontent.com/u/39814207?
# 2  https://avatars.githubusercontent.com/u/29139614?
# 3  https://avatars.githubusercontent.com/u/78318812?
# 4   https://avatars.githubusercontent.com/u/7167300?

# %%
columns = [str(col) for col in flattened.columns]
flattened.columns = ['actor' + '_' + colname for colname in columns]
flattened.head()
# Out:
#    actor_id     actor_login actor_display_login actor_gravatar_id  \
# 0  62903311           osha7               osha7
# 1  39814207       pull[bot]                pull
# 2  29139614   renovate[bot]            renovate
# 3  78318812    I-Dvorianska        I-Dvorianska
# 4   7167300  MikhailKasimov      MikhailKasimov
#
#                                      actor_url  \
# 0           https://api.github.com/users/osha7
# 1       https://api.github.com/users/pull[bot]
# 2   https://api.github.com/users/renovate[bot]
# 3    https://api.github.com/users/I-Dvorianska
# 4  https://api.github.com/users/MikhailKasimov
#
#                                     actor_avatar_url
# 0  https://avatars.githubusercontent.com/u/62903311?
# 1  https://avatars.githubusercontent.com/u/39814207?
# 2  https://avatars.githubusercontent.com/u/29139614?
# 3  https://avatars.githubusercontent.com/u/78318812?
# 4   https://avatars.githubusercontent.com/u/7167300?

# %%
data = pd.concat([data, flattened], axis=1)
data = data.drop('actor', axis=1)
data.head()
# Out:
#             id              type  \
# 0  15714140801  PullRequestEvent
# 1  15714140794         PushEvent
# 2  15714140798  PullRequestEvent
# 3  15714140795         PushEvent
# 4  15714140786         PushEvent
#
#                                                 repo  \
# 0  {'id': 344503723, 'name': 'mattenbar/wsr_backe...
# 1  {'id': 247919250, 'name': 'yefoenix/OneDrive-I...
# 2  {'id': 327661902, 'name': 'exportarts/ngx-mate...
# 3  {'id': 346134249, 'name': 'I-Dvorianska/web-st...
# 4  {'id': 133195788, 'name': 'MikhailKasimov/malt...
#
#                                              payload  public  \
# 0  {'action': 'closed', 'number': 33, 'pull_reque...    True
# 1  {'push_id': 6797947517, 'size': 0, 'distinct_s...    True
# 2  {'action': 'opened', 'number': 44, 'pull_reque...    True
# 3  {'push_id': 6797947520, 'size': 1, 'distinct_s...    True
# 4  {'push_id': 6797947510, 'size': 1, 'distinct_s...    True
#
#              created_at                                                org  \
# 0  2021-03-27T18:52:48Z                                                NaN
# 1  2021-03-27T18:52:48Z                                                NaN
# 2  2021-03-27T18:52:48Z  {'id': 34368859, 'login': 'exportarts', 'grava...
# 3  2021-03-27T18:52:48Z                                                NaN
# 4  2021-03-27T18:52:48Z                                                NaN
#
#    actor_id     actor_login actor_display_login actor_gravatar_id  \
# 0  62903311           osha7               osha7
# 1  39814207       pull[bot]                pull
# 2  29139614   renovate[bot]            renovate
# 3  78318812    I-Dvorianska        I-Dvorianska
# 4   7167300  MikhailKasimov      MikhailKasimov
#
#                                      actor_url  \
# 0           https://api.github.com/users/osha7
# 1       https://api.github.com/users/pull[bot]
# 2   https://api.github.com/users/renovate[bot]
# 3    https://api.github.com/users/I-Dvorianska
# 4  https://api.github.com/users/MikhailKasimov
#
#                                     actor_avatar_url
# 0  https://avatars.githubusercontent.com/u/62903311?
# 1  https://avatars.githubusercontent.com/u/39814207?
# 2  https://avatars.githubusercontent.com/u/29139614?
# 3  https://avatars.githubusercontent.com/u/78318812?
# 4   https://avatars.githubusercontent.com/u/7167300?

# %%
data["type"].value_counts()
# Out:
# PushEvent            15
# CreateEvent           5
# WatchEvent            3
# PullRequestEvent      3
# IssuesEvent           2
# IssueCommentEvent     2
# Name: type, dtype: int64

# %%
# ?requests.get
# Out:
# Signature: requests.get(url, params=None, **kwargs)
# Docstring:
# Sends a GET request.
#
# :param url: URL for the new :class:`Request` object.
# :param params: (optional) Dictionary, list of tuples or bytes to send
#     in the query string for the :class:`Request`.
# :param \*\*kwargs: Optional arguments that ``request`` takes.
# :return: :class:`Response <Response>` object
# :rtype: requests.Response
# File:      c:\users\mailb\anaconda3\lib\site-packages\requests\api.py
# Type:      function

# %%
res = requests.get('https://api.github.com', 
                        headers={'Accept': 'application/vnd.github.v3+json',
                                 'Authorization': f'token {github_token}'})

# %%
res.json()
# Out:
# {'current_user_url': 'https://api.github.com/user',
#  'current_user_authorizations_html_url': 'https://github.com/settings/connections/applications{/client_id}',
#  'authorizations_url': 'https://api.github.com/authorizations',
#  'code_search_url': 'https://api.github.com/search/code?q={query}{&page,per_page,sort,order}',
#  'commit_search_url': 'https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}',
#  'emails_url': 'https://api.github.com/user/emails',
#  'emojis_url': 'https://api.github.com/emojis',
#  'events_url': 'https://api.github.com/events',
#  'feeds_url': 'https://api.github.com/feeds',
#  'followers_url': 'https://api.github.com/user/followers',
#  'following_url': 'https://api.github.com/user/following{/target}',
#  'gists_url': 'https://api.github.com/gists{/gist_id}',
#  'hub_url': 'https://api.github.com/hub',
#  'issue_search_url': 'https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}',
#  'issues_url': 'https://api.github.com/issues',
#  'keys_url': 'https://api.github.com/user/keys',
#  'label_search_url': 'https://api.github.com/search/labels?q={query}&repository_id={repository_id}{&page,per_page}',
#  'notifications_url': 'https://api.github.com/notifications',
#  'organization_url': 'https://api.github.com/orgs/{org}',
#  'organization_repositories_url': 'https://api.github.com/orgs/{org}/repos{?type,page,per_page,sort}',
#  'organization_teams_url': 'https://api.github.com/orgs/{org}/teams',
#  'public_gists_url': 'https://api.github.com/gists/public',
#  'rate_limit_url': 'https://api.github.com/rate_limit',
#  'repository_url': 'https://api.github.com/repos/{owner}/{repo}',
#  'repository_search_url': 'https://api.github.com/search/repositories?q={query}{&page,per_page,sort,order}',
#  'current_user_repositories_url': 'https://api.github.com/user/repos{?type,page,per_page,sort}',
#  'starred_url': 'https://api.github.com/user/starred{/owner}{/repo}',
#  'starred_gists_url': 'https://api.github.com/gists/starred',
#  'user_url': 'https://api.github.com/users/{user}',
#  'user_organizations_url': 'https://api.github.com/user/orgs',
#  'user_repositories_url': 'https://api.github.com/users/{user}/repos{?type,page,per_page,sort}',
#  'user_search_url': 'https://api.github.com/search/users?q={query}{&page,per_page,sort,order}'}
