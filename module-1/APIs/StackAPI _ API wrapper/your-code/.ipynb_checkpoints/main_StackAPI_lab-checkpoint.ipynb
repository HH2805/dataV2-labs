# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
# your code here
import pandas as pd
from stackapi import StackAPI

SITE = StackAPI('stackoverflow')

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
questions = SITE.fetch('questions', fromdate="2021-02-01", todate="2021-02-28")

# %%
questions['items'][1]
# Out:
# {'tags': ['docker-compose'],
#  'owner': {'reputation': 33,
#   'user_id': 12584990,
#   'user_type': 'registered',
#   'profile_image': 'https://www.gravatar.com/avatar/1a74ad5683c36abf3217b8395eb09f4b?s=128&d=identicon&r=PG',
#   'display_name': 'Samuel Corsi-House',
#   'link': 'https://stackoverflow.com/users/12584990/samuel-corsi-house'},
#  'is_answered': True,
#  'view_count': 60,
#  'accepted_answer_id': 66829831,
#  'answer_count': 1,
#  'score': 0,
#  'last_activity_date': 1616855666,
#  'creation_date': 1613319714,
#  'question_id': 66197399,
#  'content_license': 'CC BY-SA 4.0',
#  'link': 'https://stackoverflow.com/questions/66197399/run-redis-insights-in-docker-compose',
#  'title': 'Run Redis Insights in Docker Compose'}

# %%
pd.DataFrame(questions['items'])
# Out:
#                                                   tags  \
# 0                     [python, cython, anaconda3, vst]
# 1                                     [docker-compose]
# 2          [firebase, flutter, google-cloud-firestore]
# 3              [tensorflow, machine-learning, pycaret]
# 4                       [equation, cubic, diophantine]
# ..                                                 ...
# 495  [amazon-web-services, elasticsearch, amazon-dy...
# 496              [maven, migration, sonatype, jcenter]
# 497     [python, configuration, celery, django-celery]
# 498                   [python, azure, azure-functions]
# 499                                 [ruby, amazon-mws]
#
#                                                  owner  is_answered  \
# 0    {'reputation': 19, 'user_id': 15279703, 'user_...        False
# 1    {'reputation': 33, 'user_id': 12584990, 'user_...         True
# 2    {'reputation': 11, 'user_id': 12491312, 'user_...         True
# 3    {'reputation': 9, 'user_id': 14939353, 'user_t...        False
# 4    {'reputation': 99, 'user_id': 14993319, 'user_...        False
# ..                                                 ...          ...
# 495  {'reputation': 1, 'user_id': 2479606, 'user_ty...        False
# 496  {'reputation': 21637, 'user_id': 12631, 'user_...         True
# 497  {'reputation': 1212, 'user_id': 3362720, 'user...         True
# 498  {'reputation': 301, 'user_id': 1100652, 'user_...        False
# 499  {'reputation': 23, 'user_id': 9814835, 'user_t...         True
#
#      view_count  answer_count  score  last_activity_date  creation_date  \
# 0            71             1      1          1616856386     1614222933
# 1            60             1      0          1616855666     1613319714
# 2            25             2      1          1616855158     1614341059
# 3            34             1      0          1616854804     1612929415
# 4            20             1     -1          1616854563     1614047196
# ..          ...           ...    ...                 ...            ...
# 495          30             1      0          1616526670     1614412701
# 496          86             1      2          1616526351     1613417556
# 497          44             2      0          1616526284     1612294213
# 498          72             0      0          1616526003     1613483202
# 499          59             2      0          1616524460     1614150536
#
#      last_edit_date  question_id content_license  \
# 0      1.614270e+09     66361882    CC BY-SA 4.0
# 1               NaN     66197399    CC BY-SA 4.0
# 2      1.616855e+09     66385522    CC BY-SA 4.0
# 3      1.612952e+09     66130711    CC BY-SA 4.0
# 4      1.614194e+09     66326199    CC BY-SA 4.0
# ..              ...          ...             ...
# 495             NaN     66396737    CC BY-SA 4.0
# 496             NaN     66214287    CC BY-SA 4.0
# 497             NaN     66016398    CC BY-SA 4.0
# 498             NaN     66225561    CC BY-SA 4.0
# 499             NaN     66346186    CC BY-SA 4.0
#
#                                                   link  \
# 0    https://stackoverflow.com/questions/66361882/c...
# 1    https://stackoverflow.com/questions/66197399/r...
# 2    https://stackoverflow.com/questions/66385522/h...
# 3    https://stackoverflow.com/questions/66130711/p...
# 4    https://stackoverflow.com/questions/66326199/d...
# ..                                                 ...
# 495  https://stackoverflow.com/questions/66396737/a...
# 496  https://stackoverflow.com/questions/66214287/h...
# 497  https://stackoverflow.com/questions/66016398/h...
# 498  https://stackoverflow.com/questions/66225561/r...
# 499  https://stackoverflow.com/questions/66346186/p...
#
#                                                  title  accepted_answer_id  \
# 0         Cython_VST_loader not installing through PIP                 NaN
# 1                 Run Redis Insights in Docker Compose          66829831.0
# 2          How to structure a like query in Firestore?                 NaN
# 3                   PyCaret ValueError - Cell is Empty                 NaN
# 4                Diophantine equations of third degree                 NaN
# ..                                                 ...                 ...
# 495                        AWS Timestream DB - AWS IOT                 NaN
# 496  How can I migrate JCenter artifact to the Sona...          66412870.0
# 497            How to use Dynaconf to configure Celery          66016578.0
# 498  Result: Failure Exception: OSError: [Errno 19]...                 NaN
# 499  Post request to selling partner API sandbox en...          66361636.0
#
#      bounty_amount  bounty_closes_date  closed_date closed_reason
# 0              NaN                 NaN          NaN           NaN
# 1              NaN                 NaN          NaN           NaN
# 2              NaN                 NaN          NaN           NaN
# 3              NaN                 NaN          NaN           NaN
# 4              NaN                 NaN          NaN           NaN
# ..             ...                 ...          ...           ...
# 495            NaN                 NaN          NaN           NaN
# 496            NaN                 NaN          NaN           NaN
# 497            NaN                 NaN          NaN           NaN
# 498            NaN                 NaN          NaN           NaN
# 499            NaN                 NaN          NaN           NaN
#
# [500 rows x 18 columns]

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
# your code here
questions = SITE.fetch('questions', fromdate='2021-03-27 00:00:01',
    min=5, tagged='python', sort='votes')
pd.DataFrame(questions['items'])
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
# your code here
answers = SITE.fetch('answers', ids=[6784, 6473])
answers['items']
# Out:
# [{'owner': {'reputation': 29473,
#    'user_id': 758,
#    'user_type': 'registered',
#    'accept_rate': 77,
#    'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=128&d=identicon&r=PG',
#    'display_name': 'Mark Renouf',
#    'link': 'https://stackoverflow.com/users/758/mark-renouf'},
#   'is_accepted': False,
#   'score': 0,
#   'last_activity_date': 1218291583,
#   'creation_date': 1218291583,
#   'answer_id': 6784,
#   'question_id': 6778,
#   'content_license': 'CC BY-SA 2.5'}]
